# %% [markdown]
# <a href="https://colab.research.google.com/github/MAHAKAGARWAL931/Data-Visualization/blob/main/Copy_of_Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#to find out hcf
#input two number
num1= int(input("enter first numbber"))
num2= int(input("enter second number"))
#------------------
if (num2==0):
    print("HCF ",num1)
else:
    while(num2 !=0):
      rem = num1%num2
      num = num2
      num2 = rem
    print("HCF:",num1)
# Out:
# enter first numbber12
# enter second number13
# HCF: 12

# %%
num = int(input("Enter a number: "))

largest = 0

while num > 0:
    digit = num % 10      # get last digit
    if digit > largest:
        largest = digit
    num = num // 10       # remove last digit

print("Greatest digit is:", largest)
# Out:
# Enter a number: 12
# Greatest digit is: 2

# %%
# to find out factorial of a number
num = int(input("Enter a number :"))
if(num<0):
  print("Not possible")
elif(num==0):
  print("Factorial is 1")
else:
  fact = 1
  for x in range(1,num+1):
    fact = fact*x
  print("Factorial : ",fact)
# Out:
# Enter a number :34
# Factorial :  295232799039604140847618609643520000000

# %%
num = int(input("Enter a number: "))

print("Even factors of", num, "are:")

for i in range(1, num + 1):
    if num % i == 0 and i % 2 == 0:
        print(i)
# Out:
# Enter a number: 12
# Even factors of 12 are:
# 2
# 4
# 6
# 12

# %%
# function to add two numbers
def addnumbers(x,y):
    return x+y
# main program
num1 = int(input("Enter first number : "))
num2 = int(input("Enter second number : "))
print("Sum : ",addnumbers(num1,num2))
# Out:
# Enter first number : 12
# Enter second number : 13
# Sum :  25

# %%
# Program to check odd or even

num = int(input("Enter a number: "))

if num % 2 == 0:
    print("The number is Even")
else:
    print("The number is Odd")
# Out:
# Enter a number: 2
# The number is Even
