# %% [markdown]
# <a href="https://colab.research.google.com/github/MAHAKAGARWAL931/Data-Visualization/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
price = float(input("Enter price: "))
discount = float(input("Enter discount percentage: "))

final_price = price - (price * discount / 100)
print("Final price after discount:", final_price)
# Out:
# Enter price: 200
# Enter discount percentage: 12
# Final price after discount: 176.0

# %%
# eligible to vote or not
age = int(input("Enter age: "))

if age >= 18:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# Enter age: 20
# Eligible
